# %%
import scipy.stats as stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1) You arrive at the train station at 10 o’clock, knowing that the train will arrive at some time **uniformly distributed** between 10 and 10:30. What is the probability that you will have to wait longer than 10 minutes?

# %%
dist = stats.uniform(loc=0, scale=30)
1 - dist.cdf(10)
# Out:
# 0.6666666666666667

# %% [markdown]
# 2) What is the probability you will have to wait less than 10 minutes?

# %%
dist.cdf(10)
# Out:
# 0.3333333333333333

# %% [markdown]
# 3) What time is in the 60th percentile of this distribution?

# %%
dist.ppf(0.60)
# Out:
# 18.0

# %% [markdown]
# 4) What is the probability the train will arrive between 10:10 and 10:20?

# %%
dist.cdf(20) - dist.cdf(10)
# Out:
# 0.3333333333333333

# %% [markdown]
# 5) Now say the arrival of trains **follows a Poisson process** where a train arrives once every half-hour. What is the probability that you will have to wait longer than 10 minutes?

# %%
dist = stats.expon(scale=30/1)
1 - dist.cdf(40)
# Out:
# 0.2635971381157267

# %% [markdown]
# 6) Knowing that it follows a Poisson process, if at 10:15 the train has not arrived, what is the probability that you will have to wait at least an additional 10 minutes?

# %%
dist.cdf(25)-dist.cdf(15)
# Out:
# 0.17193245120555523

# %% [markdown]
# 7) At what time does the train have the highest chance of arriving? Create the appropriate graph that corresponds with this belief.

# %%
df = pd.DataFrame()
df['value'] = np.linspace(dist.ppf(0.01), dist.ppf(0.99), 100)
df['PDF'] = dist.pdf(df['value'])
df['CDF'] = dist.cdf(df['value'])
df
# Out:
#          value       PDF       CDF
# 0     0.301510  0.033000  0.010000
# 1     1.693971  0.031503  0.054901
# 2     3.086431  0.030074  0.097766
# 3     4.478892  0.028710  0.138686
# 4     5.871352  0.027408  0.177751
# 5     7.263813  0.026165  0.215044
# 6     8.656273  0.024978  0.250645
# 7    10.048734  0.023846  0.284632
# 8    11.441195  0.022764  0.317077
# 9    12.833655  0.021732  0.348051
# 10   14.226116  0.020746  0.377620
# 11   15.618576  0.019805  0.405847
# 12   17.011037  0.018907  0.432795
# 13   18.403497  0.018049  0.458520
# 14   19.795958  0.017231  0.483079
# 15   21.188418  0.016449  0.506524
# 16   22.580879  0.015703  0.528905
# 17   23.973340  0.014991  0.550272
# 18   25.365800  0.014311  0.570669
# 19   26.758261  0.013662  0.590141
# 20   28.150721  0.013042  0.608730
# 21   29.543182  0.012451  0.626476
# 22   30.935642  0.011886  0.643417
# 23   32.328103  0.011347  0.659590
# 24   33.720564  0.010832  0.675029
# 25   35.113024  0.010341  0.689768
# 26   36.505485  0.009872  0.703838
# 27   37.897945  0.009424  0.717271
# 28   39.290406  0.008997  0.730094
# 29   40.682866  0.008589  0.742335
# ..         ...       ...       ...
# 70   97.773749  0.001281  0.961578
# 71   99.166210  0.001223  0.963321
# 72  100.558670  0.001167  0.964984
# 73  101.951131  0.001114  0.966572
# 74  103.343592  0.001064  0.968088
# 75  104.736052  0.001015  0.969536
# 76  106.128513  0.000969  0.970917
# 77  107.520973  0.000925  0.972236
# 78  108.913434  0.000883  0.973496
# 79  110.305894  0.000843  0.974698
# 80  111.698355  0.000805  0.975845
# 81  113.090815  0.000769  0.976941
# 82  114.483276  0.000734  0.977987
# 83  115.875737  0.000700  0.978985
# 84  117.268197  0.000669  0.979938
# 85  118.660658  0.000638  0.980848
# 86  120.053118  0.000609  0.981717
# 87  121.445579  0.000582  0.982546
# 88  122.838039  0.000555  0.983338
# 89  124.230500  0.000530  0.984093
# 90  125.622961  0.000506  0.984815
# 91  127.015421  0.000483  0.985503
# 92  128.407882  0.000461  0.986161
# 93  129.800342  0.000440  0.986789
# 94  131.192803  0.000420  0.987388
# 95  132.585263  0.000401  0.987960
# 96  133.977724  0.000383  0.988506
# 97  135.370184  0.000366  0.989027
# 98  136.762645  0.000349  0.989525
# 99  138.155106  0.000333  0.990000
#
# [100 rows x 3 columns]

# %%
df[df['PDF'] == df['PDF'].max()]
# Out:
#      value    PDF   CDF
# 0  0.30151  0.033  0.01

# %%
plt.plot(df['value'], df['PDF'])

# %% [markdown]
# 8) Say the results for the midterm for this class have an average of 70 and a standard deviation of 10 (SCARY). What is the probability that a given student has scored over a 90 on the test? How many standard deviations away from the mean is this score?

# %%
mean=70
std=10
dist = stats.norm(mean,std)
1-dist.cdf(90)
# Out:
# 0.02275013194817921

# %%
z=(90-mean)/std
z
# Out:
# 2.0

# %% [markdown]
# 9) What is the probability that a given student has scored below a 65 on the test?

# %%
dist.cdf(65)
# Out:
# 0.3085375387259869

# %% [markdown]
# 10) What is the probability that a given student has scored between a 75 and an 85 on the test?

# %%
dist.cdf(85)-dist.cdf(75)
# Out:
# 0.2417303374571288

# %% [markdown]
# 11) What is the score that is most likely to occur? Create the appropriate graph that corresponds with this belief.

# %%
df = pd.DataFrame()
df['value'] = np.linspace(dist.ppf(0.01), dist.ppf(0.99), 100)
df['PDF'] = dist.pdf(df['value'])
df['CDF'] = dist.cdf(df['value'])
df
# Out:
#         value       PDF       CDF
# 0   46.736521  0.002665  0.010000
# 1   47.206491  0.002970  0.011323
# 2   47.676460  0.003302  0.012796
# 3   48.146429  0.003663  0.014431
# 4   48.616398  0.004055  0.016244
# 5   49.086368  0.004479  0.018248
# 6   49.556337  0.004936  0.020459
# 7   50.026306  0.005428  0.022893
# 8   50.496275  0.005955  0.025566
# 9   50.966245  0.006520  0.028496
# 10  51.436214  0.007122  0.031700
# 11  51.906183  0.007762  0.035196
# 12  52.376152  0.008442  0.039002
# 13  52.846122  0.009161  0.043137
# 14  53.316091  0.009919  0.047619
# 15  53.786060  0.010716  0.052467
# 16  54.256030  0.011552  0.057698
# 17  54.725999  0.012426  0.063331
# 18  55.195968  0.013336  0.069383
# 19  55.665937  0.014281  0.075871
# 20  56.135907  0.015259  0.082811
# 21  56.605876  0.016268  0.090218
# 22  57.075845  0.017306  0.098107
# 23  57.545814  0.018370  0.106489
# 24  58.015784  0.019455  0.115376
# 25  58.485753  0.020560  0.124779
# 26  58.955722  0.021679  0.134704
# 27  59.425691  0.022809  0.145157
# 28  59.895661  0.023945  0.156144
# 29  60.365630  0.025081  0.167664
# ..        ...       ...       ...
# 70  79.634370  0.025081  0.832336
# 71  80.104339  0.023945  0.843856
# 72  80.574309  0.022809  0.854843
# 73  81.044278  0.021679  0.865296
# 74  81.514247  0.020560  0.875221
# 75  81.984216  0.019455  0.884624
# 76  82.454186  0.018370  0.893511
# 77  82.924155  0.017306  0.901893
# 78  83.394124  0.016268  0.909782
# 79  83.864093  0.015259  0.917189
# 80  84.334063  0.014281  0.924129
# 81  84.804032  0.013336  0.930617
# 82  85.274001  0.012426  0.936669
# 83  85.743970  0.011552  0.942302
# 84  86.213940  0.010716  0.947533
# 85  86.683909  0.009919  0.952381
# 86  87.153878  0.009161  0.956863
# 87  87.623848  0.008442  0.960998
# 88  88.093817  0.007762  0.964804
# 89  88.563786  0.007122  0.968300
# 90  89.033755  0.006520  0.971504
# 91  89.503725  0.005955  0.974434
# 92  89.973694  0.005428  0.977107
# 93  90.443663  0.004936  0.979541
# 94  90.913632  0.004479  0.981752
# 95  91.383602  0.004055  0.983756
# 96  91.853571  0.003663  0.985569
# 97  92.323540  0.003302  0.987204
# 98  92.793509  0.002970  0.988677
# 99  93.263479  0.002665  0.990000
#
# [100 rows x 3 columns]

# %%
df[df['PDF'] == df['PDF'].max()]
# Out:
#         value       PDF       CDF
# 49  69.765015  0.039883  0.490626
# 50  70.234985  0.039883  0.509374

# %%
plt.plot(df['value'], df['PDF'])

# %% [markdown]
# 12) What score is in the 72nd percentile?

# %%
dist.ppf(0.72)
# Out:
# 75.82841507271216
